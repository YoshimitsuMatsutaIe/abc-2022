# %% [markdown]
# # グラフ化
# C++で計算したデータをグラフで確認する．

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## y'=ax
# ### オイラー法
# csv読み込み

# %%
data_exp_e = pd.read_csv("exp_euler.csv")
data_exp_e.head()
# Out:
#      t       x
# 0  0.0  1.0000
# 1  0.1  1.1000
# 2  0.2  1.2100
# 3  0.3  1.3310
# 4  0.4  1.4641

# %% [markdown]
# グラフ化

# %%
plt.plot(data_exp_e["t"], data_exp_e["x"], label="euler")
plt.legend()

# %% [markdown]
# ### ルンゲクッタ法

# %%
data_exp_rk = pd.read_csv("exp_runge_kutta.csv")
data_exp_rk.head()
# Out:
#      t         x
# 0  0.0  1.000000
# 1  0.1  1.105171
# 2  0.2  1.221403
# 3  0.3  1.349858
# 4  0.4  1.491824

# %% [markdown]
# プロット

# %%
plt.plot(data_exp_e["t"], data_exp_e["x"], label="euler")
plt.plot(data_exp_rk["t"], data_exp_rk["x"], label="runge kutta")
plt.legend()

# %% [markdown]
# ### 厳密解と比較

# %%
data_a = np.exp(data_exp_e["t"])  # 厳密解

plt.plot(data_exp_e["t"], data_exp_e["x"], label="euler")
plt.plot(data_exp_rk["t"], data_exp_rk["x"], label="runge kutta", marker=".")
plt.plot(data_exp_e["t"], data_a, label="analysis")
plt.legend()

# %% [markdown]
# ****
# ## ローレンツ方程式
# 読み込み

# %%
data_lorenz = pd.read_csv('lorenz_runge_kutta.csv')
data_lorenz.head()
# Out:
#       t         x         y          z
# 0  0.00  0.000000  4.000000  28.000000
# 1  0.01  0.378739  3.960902  27.453175
# 2  0.02  0.717895  3.926086  26.931105
# 3  0.03  1.021797  3.898618  26.431640
# 4  0.04  1.294618  3.880839  25.952958

# %% [markdown]
# プロット

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.plot(data_lorenz['x'], data_lorenz['y'], data_lorenz['z'])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
# Out:
# Text(0.5, 0, 'z')
