# %% [markdown]
# # データの保存
#
#
# ## ソルバを利用した場合
# 公式ページにある方法 : [https://diffeq.sciml.ai/stable/features/io/#io](https://diffeq.sciml.ai/stable/features/io/#io)

# %%
using DifferentialEquations
using ParameterizedFunctions
using DataFrames
using CSV

# %% [markdown]
# ### データ用意
# ローレンツ方程式の解を利用する．

# %%
lorenz = @ode_def begin
    dx = -p*x + p*y
    dy = -x*z + r*x -y
    dz = x*y - b*z
end p r b

x₀ = [0.0, 4.0, 28.0]
p = 10
r = 28
b = 8/3
t_span = (0, 50.0)

prob = ODEProblem(lorenz, x₀, t_span, (p, r, b))
sol = solve(prob);

# %% [markdown]
# ### データフレームに変換

# %%
df = DataFrame(sol)
# Out:
# 675×4 DataFrame
#  Row │ timestamp     x             y          z
#      │ Float64       Float64       Float64    Float64
# ─────┼────────────────────────────────────────────────
#    1 │  0.0            0.0           4.0      28.0
#    2 │  3.53503e-5     0.00141374    3.99986  27.9974
#    3 │  0.000388853    0.0155209     3.99844  27.971
#    4 │  0.00392388     0.153613      3.98439  27.7098
#    5 │  0.0203338      0.728676      3.92689  26.552
#    6 │  0.0461821      1.45155       3.89418  24.8916
#    7 │  0.0747683      2.06748       3.98402  23.2568
#    8 │  0.110921       2.69736       4.32772  21.4615
#   ⋮  │      ⋮             ⋮            ⋮         ⋮
#  669 │ 49.6296        -0.130272     -2.18188  22.5574
#  670 │ 49.698         -1.17945      -2.40304  18.8984
#  671 │ 49.7585        -1.91396      -3.21962  16.3264
#  672 │ 49.83          -3.08893      -5.19483  14.17
#  673 │ 49.9059        -5.28284      -9.10951  13.6097
#  674 │ 49.9974       -10.0221      -16.3645   18.7307
#  675 │ 50.0          -10.1902      -16.5646   19.0377
#                                       660 rows omitted

# %% [markdown]
# ### CSV形式で保存

# %%
CSV.write("lorenz.csv", df)
# Out:
# "lorenz.csv"

# %% [markdown]
# ### csvの読み込み
# データフレームとして読み込む

# %%
sol_read = CSV.read("lorenz.csv", DataFrame)
# Out:
# 675×4 DataFrame
#  Row │ timestamp     x             y          z
#      │ Float64       Float64       Float64    Float64
# ─────┼────────────────────────────────────────────────
#    1 │  0.0            0.0           4.0      28.0
#    2 │  3.53503e-5     0.00141374    3.99986  27.9974
#    3 │  0.000388853    0.0155209     3.99844  27.971
#    4 │  0.00392388     0.153613      3.98439  27.7098
#    5 │  0.0203338      0.728676      3.92689  26.552
#    6 │  0.0461821      1.45155       3.89418  24.8916
#    7 │  0.0747683      2.06748       3.98402  23.2568
#    8 │  0.110921       2.69736       4.32772  21.4615
#   ⋮  │      ⋮             ⋮            ⋮         ⋮
#  669 │ 49.6296        -0.130272     -2.18188  22.5574
#  670 │ 49.698         -1.17945      -2.40304  18.8984
#  671 │ 49.7585        -1.91396      -3.21962  16.3264
#  672 │ 49.83          -3.08893      -5.19483  14.17
#  673 │ 49.9059        -5.28284      -9.10951  13.6097
#  674 │ 49.9974       -10.0221      -16.3645   18.7307
#  675 │ 50.0          -10.1902      -16.5646   19.0377
#                                       660 rows omitted
